# %%
# import
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, func
import psycopg2

# %%
#csvs to dataframes
hate_crimeDF = pd.read_csv('static/templates/hate_crime.csv')
latlngDF = pd.read_csv('static/templates/state_latlng.csv')
# Out:
# C:\Users\jacob\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#changing column names
latlngDF.columns = ["state_abbr", "latitude", "longitude", "state_name"]
#removing state abbr, already in hate_crimes csv
latlngDF.drop('state_abbr', inplace=True, axis=1)
latlngDF.head()
# Out:
#     latitude   longitude   state_name
# 0  63.588753 -154.493062       Alaska
# 1  32.318231  -86.902298      Alabama
# 2  35.201050  -91.831833     Arkansas
# 3  34.048928 -111.093731      Arizona
# 4  36.778261 -119.417932   California

# %%
#dropping unnecessary rows
to_drop = ['ORI',
            'PUB_AGENCY_UNIT',
            'DIVISION_NAME',
            'OFFENDER_RACE',
            'OFFENDER_ETHNICITY',
            'VICTIM_COUNT',
            'OFFENSE_NAME',
            'LOCATION_NAME',
            'VICTIM_TYPES',
            'MULTIPLE_OFFENSE',
            'MULTIPLE_BIAS',
            'POPULATION_GROUP_CODE',
            'POPULATION_GROUP_DESC',
            'ADULT_VICTIM_COUNT',
            'JUVENILE_VICTIM_COUNT',
            'TOTAL_OFFENDER_COUNT',
            'ADULT_OFFENDER_COUNT',
            'JUVENILE_OFFENDER_COUNT']
hate_crimeDF.drop(to_drop, inplace=True, axis=1)
hate_crimeDF.head()
# Out:
#    INCIDENT_ID  DATA_YEAR PUB_AGENCY_NAME AGENCY_TYPE_NAME STATE_ABBR  \
# 0         3015       1991          Rogers             City         AR
# 1         3016       1991            Hope             City         AR
# 2           43       1991      Pine Bluff             City         AR
# 3           44       1991      Pine Bluff             City         AR
# 4         3017       1991      Pine Bluff             City         AR
#
#   STATE_NAME REGION_NAME  INCIDENT_DATE  TOTAL_INDIVIDUAL_VICTIMS  \
# 0   Arkansas       South          33481                       1.0
# 1   Arkansas       South          33500                       1.0
# 2   Arkansas       South          33423                       1.0
# 3   Arkansas       South          33596                       1.0
# 4   Arkansas       South          33595                       1.0
#
#                         BIAS_DESC
# 0  Anti-Black or African American
# 1                      Anti-White
# 2  Anti-Black or African American
# 3                      Anti-White
# 4                      Anti-White

# %%
# Checking the data types of all columns
hate_crimeDF.dtypes
# Out:
# INCIDENT_ID                   int64
# DATA_YEAR                     int64
# PUB_AGENCY_NAME              object
# AGENCY_TYPE_NAME             object
# STATE_ABBR                   object
# STATE_NAME                   object
# REGION_NAME                  object
# INCIDENT_DATE                 int64
# TOTAL_INDIVIDUAL_VICTIMS    float64
# BIAS_DESC                    object
# dtype: object

# %%
# Checking the whether the the row contains null values
hate_crimeDF.isna().sum()
# Out:
# INCIDENT_ID                    0
# DATA_YEAR                      0
# PUB_AGENCY_NAME                0
# AGENCY_TYPE_NAME               0
# STATE_ABBR                     0
# STATE_NAME                     0
# REGION_NAME                    0
# INCIDENT_DATE                  0
# TOTAL_INDIVIDUAL_VICTIMS    1606
# BIAS_DESC                      0
# dtype: int64

# %%
#removing null values
hate_crimeDF.dropna(axis=0, how='any', thresh=None, subset=['TOTAL_INDIVIDUAL_VICTIMS'], inplace=True)
hate_crimeDF.isna().sum()
# Out:
# INCIDENT_ID                 0
# DATA_YEAR                   0
# PUB_AGENCY_NAME             0
# AGENCY_TYPE_NAME            0
# STATE_ABBR                  0
# STATE_NAME                  0
# REGION_NAME                 0
# INCIDENT_DATE               0
# TOTAL_INDIVIDUAL_VICTIMS    0
# BIAS_DESC                   0
# dtype: int64

# %%
# Converting all the column heading to lower case 
hate_crimeDF = hate_crimeDF.rename(str.lower,axis='columns')
hate_crimeDF.head()
# Out:
#    incident_id  data_year pub_agency_name agency_type_name state_abbr  \
# 0         3015       1991          Rogers             City         AR
# 1         3016       1991            Hope             City         AR
# 2           43       1991      Pine Bluff             City         AR
# 3           44       1991      Pine Bluff             City         AR
# 4         3017       1991      Pine Bluff             City         AR
#
#   state_name region_name  incident_date  total_individual_victims  \
# 0   Arkansas       South          33481                       1.0
# 1   Arkansas       South          33500                       1.0
# 2   Arkansas       South          33423                       1.0
# 3   Arkansas       South          33596                       1.0
# 4   Arkansas       South          33595                       1.0
#
#                         bias_desc
# 0  Anti-Black or African American
# 1                      Anti-White
# 2  Anti-Black or African American
# 3                      Anti-White
# 4                      Anti-White

# %%
#merging csvs
hate_crimeDF = pd.merge(hate_crimeDF, latlngDF, on='state_name')
hate_crimeDF.head()
# Out:
#    incident_id  data_year pub_agency_name agency_type_name state_abbr  \
# 0         3015       1991          Rogers             City         AR
# 1         3016       1991            Hope             City         AR
# 2           43       1991      Pine Bluff             City         AR
# 3           44       1991      Pine Bluff             City         AR
# 4         3017       1991      Pine Bluff             City         AR
#
#   state_name region_name  incident_date  total_individual_victims  \
# 0   Arkansas       South          33481                       1.0
# 1   Arkansas       South          33500                       1.0
# 2   Arkansas       South          33423                       1.0
# 3   Arkansas       South          33596                       1.0
# 4   Arkansas       South          33595                       1.0
#
#                         bias_desc  latitude  longitude
# 0  Anti-Black or African American  35.20105 -91.831833
# 1                      Anti-White  35.20105 -91.831833
# 2  Anti-Black or African American  35.20105 -91.831833
# 3                      Anti-White  35.20105 -91.831833
# 4                      Anti-White  35.20105 -91.831833

# %%
# removing years that are not in consideration of our study
hate_crimeDF = hate_crimeDF[hate_crimeDF['data_year'] >= 1993]
print(hate_crimeDF.head())
print(hate_crimeDF.shape)
# Out:
#     incident_id  data_year pub_agency_name agency_type_name state_abbr  \
# 50        11390       1993      Berryville             City         AR
# 51        11391       1993       Jonesboro             City         AR
# 52        11392       1993       Jonesboro             City         AR
# 53        11393       1993       Jonesboro             City         AR
# 54        11394       1993         Newport             City         AR
#
#    state_name region_name  incident_date  total_individual_victims  \
# 50   Arkansas       South          34149                       1.0
# 51   Arkansas       South          34051                       1.0
# 52   Arkansas       South          34060                       1.0
# 53   Arkansas       South          34160                       2.0
# 54   Arkansas       South          34123                       1.0
#
#                          bias_desc  latitude  longitude
# 50  Anti-Black or African American  35.20105 -91.831833
# 51                      Anti-White  35.20105 -91.831833
# 52                      Anti-White  35.20105 -91.831833
# 53                 Anti-Gay (Male)  35.20105 -91.831833
# 54                      Anti-White  35.20105 -91.831833
# (140574, 12)

# %%
#adding administration column
administration = []
hate_crimeDF.loc[hate_crimeDF['data_year'] <= 1996, 'administration'] = "Clinton 1st Term"
hate_crimeDF.loc[(hate_crimeDF['data_year'] > 1996) & (hate_crimeDF['data_year'] <= 2000), 'administration'] = 'Clinton 2nd Term'
hate_crimeDF.loc[(hate_crimeDF['data_year'] >2000) & (hate_crimeDF['data_year'] <= 2004), 'administration'] = 'W. Bush 1st Term'
hate_crimeDF.loc[(hate_crimeDF['data_year'] > 2004) & (hate_crimeDF['data_year'] <= 2008), 'administration'] = 'W. Bush 2nd Term'
hate_crimeDF.loc[(hate_crimeDF['data_year'] > 2008) & (hate_crimeDF['data_year'] <= 2012), 'administration'] = 'Obama 1st Term'
hate_crimeDF.loc[(hate_crimeDF['data_year'] > 2012) & (hate_crimeDF['data_year'] <= 2016), 'administration'] = 'Obama 2nd Term'
hate_crimeDF.loc[hate_crimeDF['data_year'] >= 2017, 'administration'] = 'Trump 1st Term'
hate_crimeDF
# Out:
#         incident_id  data_year pub_agency_name agency_type_name state_abbr  \
# 50            11390       1993      Berryville             City         AR
# 51            11391       1993       Jonesboro             City         AR
# 52            11392       1993       Jonesboro             City         AR
# 53            11393       1993       Jonesboro             City         AR
# 54            11394       1993         Newport             City         AR
# ...             ...        ...             ...              ...        ...
# 150978       601046       2018        Honolulu             City         HI
# 150979       601047       2018        Honolulu             City         HI
# 150980       601049       2018        Honolulu             City         HI
# 150981       601053       2018        Honolulu             City         HI
# 150982       601055       2018        Honolulu             City         HI
#
#        state_name region_name  incident_date  total_individual_victims  \
# 50       Arkansas       South          34149                       1.0
# 51       Arkansas       South          34051                       1.0
# 52       Arkansas       South          34060                       1.0
# 53       Arkansas       South          34160                       2.0
# 54       Arkansas       South          34123                       1.0
# ...           ...         ...            ...                       ...
# 150978     Hawaii        West          43398                       1.0
# 150979     Hawaii        West          43372                       1.0
# 150980     Hawaii        West          43291                       1.0
# 150981     Hawaii        West          43456                       1.0
# 150982     Hawaii        West          43372                       1.0
#
#                              bias_desc   latitude   longitude  \
# 50      Anti-Black or African American  35.201050  -91.831833
# 51                          Anti-White  35.201050  -91.831833
# 52                          Anti-White  35.201050  -91.831833
# 53                     Anti-Gay (Male)  35.201050  -91.831833
# 54                          Anti-White  35.201050  -91.831833
# ...                                ...        ...         ...
# 150978                      Anti-White  19.898682 -155.665857
# 150979  Anti-Black or African American  19.898682 -155.665857
# 150980                     Anti-Jewish  19.898682 -155.665857
# 150981                      Anti-Asian  19.898682 -155.665857
# 150982  Anti-Black or African American  19.898682 -155.665857
#
#           administration
# 50      Clinton 1st Term
# 51      Clinton 1st Term
# 52      Clinton 1st Term
# 53      Clinton 1st Term
# 54      Clinton 1st Term
# ...                  ...
# 150978    Trump 1st Term
# 150979    Trump 1st Term
# 150980    Trump 1st Term
# 150981    Trump 1st Term
# 150982    Trump 1st Term
#
# [140574 rows x 13 columns]

# %%
#saving cleaned data csv
hate_crimeDF.to_csv('cleaned_hate_crime.csv',index = False)

# %%
# Create PostgreSQL RDS Database Connection
engine = create_engine("postgres+psycopg2://postgres:project2group2@127.0.0.1:5432/Project_2_DB")
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-20-e3346d778395> in <module>
#       1 # Create PostgreSQL RDS Database Connection
#       2 engine = create_engine("postgres+psycopg2://postgres:project2group2@127.0.0.1:5432/Project_2_DB")
# ----> 3 conn = engine.connect()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2264         """
#    2265
# -> 2266         return self._connection_cls(self, **kwargs)
#    2267
#    2268     @util.deprecated(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     102                 connection
#     103                 if connection is not None
# --> 104                 else engine.raw_connection()
#     105             )
#     106             self.__transaction = None
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2371         """
#    2372         return self._wrap_pool_connect(
# -> 2373             self.pool.unique_connection, _connection
#    2374         )
#    2375
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2341             if connection is None:
#    2342                 Connection._handle_dbapi_exception_noconnection(
# -> 2343                     e, dialect, self
#    2344                 )
#    2345             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1583         elif should_wrap:
#    1584             util.raise_(
# -> 1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#    1587         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     302
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#     306     def _create_connection(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Check table names
engine.table_names()
# Out:
# ['hate_crimes']

# %%
hate_crimeDF.to_sql('hate_crimes', conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-195910db0271> in <module>
# ----> 1 hate_crimeDF.to_sql('hate_crimes', conn)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     644         if self.exists():
#     645             if self.if_exists == "fail":
# --> 646                 raise ValueError(f"Table '{self.name}' already exists.")
#     647             elif self.if_exists == "replace":
#     648                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'hate_crimes' already exists.

# %%
pd.read_sql_query('select * from hate_crimes', con=engine).head()
